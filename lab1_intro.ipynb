# %% [markdown]
# To run in Colab,
# * click this button
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ssuai/machine_learning/blob/main/lab1_intro.ipynb)
# * run the following cell

# %%
# clone the data folder only
# !git clone https://github.com/ssuai/machine_learning_data.git data
# # clone the whole repo
# !git clone --recurse-submodules https://github.com/ssuai/machine_learning.git
# # move into the folder to access `data` folder
# %cd machine_learning

# %% [markdown]
# # Lab 1. Introduction to  *Python*

# %% [markdown]
# ## Jupyter Notebooks
# * What is Jupyter notebook? Check [here](https://github.com/ys7yoo/PyBasic/blob/master/README.md#3-jupyter-notebook).
# * We will use [Google Colab](https://colab.research.google.com) to run and edit notebooks.
# * There are many other ["cloud" services] https://www.dataschool.io/cloud-services-for-jupyter-notebook/ for Jupyter notebooks.
# * To run notebooks on your local machine, see [here](https://github.com/ys7yoo/PyBasic/blob/master/README.md#2-setting-up-python-environment) for more general information for set up Python environment.

# %% [markdown]
# ## 1. Plot data using `matplotlib`
#
#
# See [here](https://matplotlib.org/stable/tutorials/index.html) for official `matplotlib` tutorial

# %%
# standard package for numerical calculations  
import numpy as np                 

# standard package for plotting!
import matplotlib.pyplot as plt

# %%
# generate 100 samples from normal distribution
x = np.random.randn(100)
y = np.random.randn(100)

# %%
# simple
plt.plot(x,y, '.')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of X vs. Y')
# Out:
# Text(0.5, 1.0, 'Plot of X vs. Y')

# %%
# the scatter plot
plt.scatter(x,y, s=20, alpha=0.8)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter plot of X vs. Y')
# Out:
# Text(0.5, 1.0, 'Scatter plot of X vs. Y')

# %% [markdown]
# ## 2. Load data using `pandas`
#
# Good references on `pandas`:
# * [Officeial pandas tutorial](https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html)
#
# * [10 Minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/10min.html)

# %%
# let's import pandas
import pandas as pd

# %%
# read Auto data
Auto = pd.read_csv('data/Auto.csv', na_values='?')  # => DataFrame
# show only head
print(Auto.shape)                    # size = 397 x 9
Auto.head()
# Out:
# (397, 9)
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# an example of missing data
Auto.loc[32]
# Out:
# mpg                   25.0
# cylinders                4
# displacement          98.0
# horsepower             NaN
# weight                2046
# acceleration          19.0
# year                    71
# origin                   1
# name            ford pinto
# Name: 32, dtype: object

# %%
# take care of missing data
Auto = Auto.dropna()
print(Auto.shape)     # now we have 392 x 9
# Out:
# (392, 9)

# %%
# get column names
list(Auto)
# equivalently, 
#Auto.columns.values.tolist()
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'year',
#  'origin',
#  'name']

# %%
# get a column => Series
Auto['mpg']
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 392    27.0
# 393    44.0
# 394    32.0
# 395    28.0
# 396    31.0
# Name: mpg, Length: 392, dtype: float64

# %%
# plot histogram of mpg
plt.hist(Auto['mpg'])
plt.xlabel('mpg')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
# plot cylinders vs mpg
plt.plot(Auto['cylinders'], Auto['mpg'], '.', alpha=0.2)
plt.xlabel('cylinders')
plt.ylabel('mpg')
# Out:
# Text(0, 0.5, 'mpg')

# %%
#Equivalently
Auto.plot.scatter(x='cylinders', y='mpg', alpha=0.2)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='mpg'>

# %%
# use "group-by" to plot boxplot for each cylinder types
Auto.boxplot(column='mpg', by='cylinders')
# Out:
# <AxesSubplot:title={'center':'mpg'}, xlabel='cylinders'>
